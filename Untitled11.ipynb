# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
import numpy as np


data = pd.read_csv('Week14Assignment.txt', sep=", ")


readmitted_patients = data[data['Readmission'] == 1].shape[0]
print(f"Number of Patients Readmitted: {readmitted_patients}")


categories = ['StaffSatisfaction', 'CleanlinessSatisfaction', 'FoodSatisfaction', 'ComfortSatisfaction', 'CommunicationSatisfaction']
for category in categories:
    avg_score = data[category].mean()
    print(f"Average {category}: {avg_score:.2f}")


X = data[categories]
y = data['Readmission']
log_reg = LogisticRegression().fit(X, y)


print("\nLogistic Regression Results:")
print("----------------------------")
print(f"Correlation between Overall Satisfaction Scores and Readmission: {log_reg.score(X, y):.2f}")


plt.figure(figsize=(10, 6))
plt.scatter(data['PatientID'], data['Readmission'], color='blue', label='data')
plt.plot(data['PatientID'], log_reg.predict_proba(X)[:, 1], color='red', label='logistic regression curve')
plt.xlabel('PatientID')
plt.ylabel('Readmission')
plt.legend()
plt.show()
# Out:
# C:\Users\asimt\AppData\Local\Temp\ipykernel_13224\1748361627.py:7: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv('Week14Assignment.txt', sep=", ")
# Number of Patients Readmitted: 15
# Average StaffSatisfaction: 3.50
# Average CleanlinessSatisfaction: 3.60
# Average FoodSatisfaction: 3.53
# Average ComfortSatisfaction: 3.73
# Average CommunicationSatisfaction: 3.70
#
# Logistic Regression Results:
# ----------------------------
# Correlation between Overall Satisfaction Scores and Readmission: 0.80
